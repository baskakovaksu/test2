# %%
import pandas as pd

# %%
D = pd.read_excel("https://github.com/junaart/ForStudents/raw/refs/heads/main/R/Zachet/DataSets/1.xlsx")

# %%
display(D)
# Out:
#                  town1  Avg-Avg-Р41  Avg-Avg-Р42  Avg-Avg-Р43  Avg-Avg-Р44  \
# 0               Абакан    11.000000     4.000000     0.000000    69.500000
# 1       Азовский район     0.666667     0.000000     1.000000     0.000000
# 2      Аксайский район     3.250000     0.500000     5.500000     9.750000
# 3    Алексеевкий район     0.000000     0.000000     0.000000     0.000000
# 4                Анапа     0.500000     0.000000     0.000000     2.500000
# ..                 ...          ...          ...          ...          ...
# 276     Южно-Сахалинск    12.200000     0.400000    63.800000     7.550000
# 277             Якутск    10.266667     2.800000     3.050000     7.583333
# 278               Ялта     2.333333     3.833333    12.833333    17.000000
# 279          Ярославль    43.964286     7.785714     0.142857     2.642857
# 280  Ярославский район     1.666667     0.000000     0.000000     2.000000
#
# ...

# %%
import redis as rd

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р41"
for i in range(len(D['Avg-Avg-Р41'])):
    r.set(key+str(i),str(D['Avg-Avg-Р41'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р42"
for i in range(len(D['Avg-Avg-Р42'])):
    r.set(key+str(i),str(D['Avg-Avg-Р42'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р43"
for i in range(len(D['Avg-Avg-Р43'])):
    r.set(key+str(i),str(D['Avg-Avg-Р43'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р44"
for i in range(len(D['Avg-Avg-Р44'])):
    r.set(key+str(i),str(D['Avg-Avg-Р44'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р51"
for i in range(len(D['Avg-Avg-Р51'])):
    r.set(key+str(i),str(D['Avg-Avg-Р51'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р53"
for i in range(len(D['Avg-Avg-Р53'])):
    r.set(key+str(i),str(D['Avg-Avg-Р53'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р61"
for i in range(len(D['Avg-Avg-Р61'])):
    r.set(key+str(i),str(D['Avg-Avg-Р61'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р62"
for i in range(len(D['Avg-Avg-Р62'])):
    r.set(key+str(i),str(D['Avg-Avg-Р62'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р63"
for i in range(len(D['Avg-Avg-Р63'])):
    r.set(key+str(i),str(D['Avg-Avg-Р63'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р64"
for i in range(len(D['Avg-Avg-Р64'])):
    r.set(key+str(i),str(D['Avg-Avg-Р64'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р71"
for i in range(len(D['Avg-Avg-Р71'])):
    r.set(key+str(i),str(D['Avg-Avg-Р71'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р772"
for i in range(len(D['Avg-Avg-Р72'])):
    r.set(key+str(i),str(D['Avg-Avg-Р72'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "Avg-Avg-Р7"
for i in range(len(D['Avg-Avg-Р7'])):
    r.set(key+str(i),str(D['Avg-Avg-Р7'].iloc[i]))
